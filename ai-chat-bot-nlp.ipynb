# %%
# for speech to text
# !pip install SpeechRecognition  
# for text to speech
# !pip install gTTS  
# for language modelimport numpy as np

# !pip install transformers  
# !pip install tensorflow
# Out:
# Requirement already satisfied: SpeechRecognition in c:\users\dell\anaconda3\lib\site-packages (3.9.0)
# Requirement already satisfied: requests>=2.26.0 in c:\users\dell\anaconda3\lib\site-packages (from SpeechRecognition) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (1.26.9)
# Requirement already satisfied: gTTS in c:\users\dell\anaconda3\lib\site-packages (2.3.1)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\dell\anaconda3\lib\site-packages (from gTTS) (2.27.1)
# Requirement already satisfied: click<8.2,>=7.1 in c:\users\dell\anaconda3\lib\site-packages (from gTTS) (8.0.4)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\lib\site-packages (from click<8.2,>=7.1->gTTS) (0.4.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from requests<3,>=2.27->gTTS) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests<3,>=2.27->gTTS) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests<3,>=2.27->gTTS) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests<3,>=2.27->gTTS) (1.26.9)
# Requirement already satisfied: transformers in c:\users\dell\anaconda3\lib\site-packages (4.21.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\dell\anaconda3\lib\site-packages (from transformers) (2022.3.15)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in c:\users\dell\anaconda3\lib\site-packages (from transformers) (0.8.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\anaconda3\lib\site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\dell\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: requests in c:\users\dell\anaconda3\lib\site-packages (from transformers) (2.27.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\dell\anaconda3\lib\site-packages (from transformers) (1.21.5)
# Requirement already satisfied: filelock in c:\users\dell\anaconda3\lib\site-packages (from transformers) (3.6.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\dell\anaconda3\lib\site-packages (from transformers) (4.64.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in c:\users\dell\anaconda3\lib\site-packages (from transformers) (0.12.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\dell\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\dell\anaconda3\lib\site-packages (from packaging>=20.0->transformers) (3.0.4)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests->transformers) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests->transformers) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: tensorflow in c:\users\dell\anaconda3\lib\site-packages (2.9.1)
# Requirement already satisfied: setuptools in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (61.2.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (3.19.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (14.0.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: flatbuffers<2,>=1.12 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (0.26.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (1.21.5)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (4.1.1)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: packaging in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (21.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\dell\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.27.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\dell\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\dell\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\dell\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.0.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\dell\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.33.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\dell\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dell\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\dell\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\dell\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\dell\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\dell\anaconda3\lib\site-packages (from packaging->tensorflow) (3.0.4)

# %%
import numpy as np

# %%
# !pip install PyAudio

# %%
"""
import speech_recognition as sr

class ChatBot():
    def __init__(self, name):
        print("--- starting up", name, "---")
        self.name = name

    def speech_to_text(self):
        recognizer = sr.Recognizer()
        with sr.Microphone() as mic:
             recognizer.adjust_for_ambient_noise(mic, duration=1)            
             print("listening...")
             audio = recognizer.listen(mic)
                
             self.text = recognizer.recognize_google(audio)
             print("me --> ", self.text)
        
        

if __name__ == "__main__":
     ai = ChatBot(name="maya")
     while True:
         ai.speech_to_text()
"""
# Out:
# --- starting up maya ---
# listening...
# result2:
# {   'alternative': [   {   'confidence': 0.86299628,
#                            'transcript': 'yah Maine Kya Kahana function karo'},
#                        {   'transcript': 'yah Maine Kya Kahana define function '
#                                          'karo'},
#                        {   'transcript': 'yah Maine Kya Kahana ki aap class '
#                                          'class board ke andar yah define '
#                                          'function karo'}],
#     'final': True}
# me -->  yah Maine Kya Kahana function karo
# listening...
# result2:
# {   'alternative': [   {   'confidence': 0.8147682,
#                            'transcript': 'phone Karte Hain To problem'},
#                        {'transcript': 'phone Karte Hain'},
#                        {'transcript': 'phone karte hain complete'},
#                        {'transcript': 'phone karte hain pura complete'},
#                        {'transcript': 'phone karte hain lekin pura complete'}],
#     'final': True}
# me -->  phone Karte Hain To problem
# listening...
# result2:
# {   'alternative': [   {   'confidence': 0.88687521,
#                            'transcript': 'Achcha jo abhi aapko batai Na vahi '
#                                          'hai aapko yah audio record kara '
#                                          'Mera'},
#                        {   'transcript': 'Achcha jo abhi aapko batai Na vahi '
#                                          'hai aapko yah audio record kara Mera '
#                                          'class function ke andar class'},
#                        {   'transcript': 'Achcha jo abhi aapko batai Na vahi '
#                                          'hai aapko yah audio record kara Mera '
#                                          'pahle class function ke andar class'},
#                        {   'transcript': 'Achcha jo abhi aapko batai Na vahi '
#                                          'hai aapko yah audio record kara '
#                                          'merath board ke andar class'},
#                        {   'transcript': 'Achcha jo abhi aapko batai Na vahi '
#                                          'hai aapko yah audio record kara Mera '
#                                          'class'}],
#     'final': True}
# me -->  Achcha jo abhi aapko batai Na vahi hai aapko yah audio record kara Mera
# listening...
# result2:
# {   'alternative': [   {   'confidence': 0.86205995,
#                            'transcript': 'speech to text to vo kam dikhegi'},
#                        {'transcript': 'speech to text to vah kam dikhegi'},
#                        {'transcript': 'speech to text to vo kam dikhe'},
#                        {'transcript': 'speech to text'},
#                        {'transcript': 'speech to text to vah kam dikhe'}],
#     'final': True}
# me -->  speech to text to vo kam dikhegi
# listening...
# result2:
# {   'alternative': [   {'confidence': 0.71610451, 'transcript': 'kahan per'},
#                        {'transcript': 'Aap Jo bol rahe ho'},
#                        {'transcript': 'kahan per le rahe hain'},
#                        {'transcript': 'kahan per Ho'}],
#     'final': True}
# me -->  kahan per
# listening...
# result2:
# []
# ---------------------------------------------------------------------------
# UnknownValueError                         Traceback (most recent call last)
# Input In [4], in <cell line: 20>()
#      21 ai = ChatBot(name="maya")
#      22 while True:
# ---> 23     ai.speech_to_text()
#
# Input In [4], in ChatBot.speech_to_text(self)
#      12 print("listening...")
#      13 audio = recognizer.listen(mic)
# ---> 15 self.text = recognizer.recognize_google(audio)
#      16 print("me --> ", self.text)
#
# File ~\anaconda3\lib\site-packages\speech_recognition\__init__.py:919, in Recognizer.recognize_google(self, audio_data, key, language, pfilter, show_all, with_confidence)
#     917 print('result2:')
#     918 pprint(actual_result, indent=4)
# --> 919 if not isinstance(actual_result, dict) or len(actual_result.get("alternative", [])) == 0: raise UnknownValueError()
#     921 if "confidence" in actual_result["alternative"]:
#     922     # return alternative with highest confidence score
#     923     best_hypothesis = max(actual_result["alternative"], key=lambda alternative: alternative["confidence"])
#
# UnknownValueError:

# %%
## for language model
import transformers

## for data
#import os
import datetime
import numpy as np

# %%
from gtts import gTTS
import os

# %%
import speech_recognition as sr

# %%
pip install pyttsx3
# Out:
# Collecting pyttsx3Note: you may need to restart the kernel to use updated packages.
#
#   Downloading pyttsx3-2.90-py3-none-any.whl (39 kB)
# Requirement already satisfied: comtypes in c:\users\dell\anaconda3\lib\site-packages (from pyttsx3) (1.1.10)
# Collecting pypiwin32
#   Downloading pypiwin32-223-py3-none-any.whl (1.7 kB)
# Requirement already satisfied: pywin32 in c:\users\dell\anaconda3\lib\site-packages (from pyttsx3) (302)
# Installing collected packages: pypiwin32, pyttsx3
# Successfully installed pypiwin32-223 pyttsx3-2.90

# %%
import pyttsx3

# %%
# Build the AI
class ChatBot():
    def __init__(self, name):
        print("--- starting up", name, "---")
        self.name = name
        
    def speech_to_text(self):
        recognizer = sr.Recognizer()
        with sr.Microphone() as mic:
             recognizer.adjust_for_ambient_noise(mic, duration=1)            
             print("listening...")
             audio = recognizer.listen(mic)
        try:
             self.text = recognizer.recognize_google(audio)
             print("me --> ", self.text)
        except:
             print("me -->  ERROR")
    
    @staticmethod
    def text_to_speech(text):
        print("ai --> ", text)
        engine = pyttsx3.init()
        engine.say(text)
        engine.runAndWait()

    def wake_up(self, text):
        return True if self.name in text.lower() else False
    
    @staticmethod
    def action_time():
        return datetime.datetime.now().time().strftime('%H:%M')

        # Run the AI
if __name__ == "__main__":
    ai = ChatBot(name="maya")
    nlp = transformers.pipeline("conversational", model="microsoft/DialoGPT-medium")
    os.environ["TOKENIZERS_PARALLELISM"] = "true"

    while True:
        ai.speech_to_text()

            ## wake up
        if ai.wake_up(ai.text) is True:
            res = "Hello I am Maya the AI, what can I do for you?"

            ## action time
        elif "time" in ai.text:
            res = ai.action_time()

            ## respond politely
        elif any(i in ai.text for i in ["thank","thanks"]):
            res = np.random.choice(["you're welcome!","anytime!","no problem!","cool!","I'm here if you need me!","peace out!"])

            ## conversation
        else:   
            chat = nlp(transformers.Conversation(ai.text), pad_token_id=50256)
            res = str(chat)
            res = res[res.find("bot >> ")+6:].strip()

        ai.text_to_speech(res)
# Out:
# --- starting up maya ---
# All model checkpoint layers were used when initializing TFGPT2LMHeadModel.
#
# All the layers of TFGPT2LMHeadModel were initialized from the model checkpoint at microsoft/DialoGPT-medium.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2LMHeadModel for predictions without further training.
# listening...
# result2:
# {   'alternative': [   {   'confidence': 0.87738818,
#                            'transcript': 'hi Maya how are you hi Maya how are '
#                                          'you'},
#                        {'transcript': 'hi Maya how are you how are you'},
#                        {'transcript': 'hi Maya how are you'}],
#     'final': True}
# me -->  hi Maya how are you hi Maya how are you
# ai -->  Hello I am Maya the AI, what can I do for you?
# listening...
# result2:
# {   'alternative': [   {   'confidence': 0.86936975,
#                            'transcript': 'ab niche wala Jo code hai na last '
#                                          'wala'},
#                        {'transcript': 'ab niche wala Jo code hai na last'},
#                        {'transcript': 'niche wala Jo code hai na last wala'},
#                        {'transcript': 'ab niche wala Jo code hai na'},
#                        {'transcript': 'niche wala Jo code hai na last'}],
#     'final': True}
# me -->  ab niche wala Jo code hai na last wala
# ai -->  I'm not sure if you're being serious or not, but I'm going to go with the latter.
# listening...
# result2:
# []
# me -->  ERROR
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [29], in <cell line: 34>()
#      52     res = np.random.choice(["you're welcome!","anytime!","no problem!","cool!","I'm here if you need me!","peace out!"])
#      54     ## conversation
#      55 else:
# ---> 56     chat = nlp(transformers.Conversation(ai.text), pad_token_id=50256)
#      57     res = str(chat)
#      58     res = res[res.find("bot >> ")+6:].strip()
#
# File ~\anaconda3\lib\site-packages\transformers\pipelines\conversational.py:239, in ConversationalPipeline.__call__(self, conversations, num_workers, **kwargs)
#     219 r"""
#     220 Generate responses for the conversation(s) given as inputs.
#     221
#    (...)
#     233     containing a new user input.
#     234 """
#     235 # XXX: num_workers==0 is required to be backward compatible
#     236 # Otherwise the threads will require a Conversation copy.
#     237 # This will definitely hinder performance on GPU, but has to be opted
#     238 # in because of this BC change.
# --> 239 outputs = super().__call__(conversations, num_workers=num_workers, **kwargs)
#     240 if isinstance(outputs, list) and len(outputs) == 1:
#     241     return outputs[0]
#
# File ~\anaconda3\lib\site-packages\transformers\pipelines\base.py:1067, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1065     return self.iterate(inputs, preprocess_params, forward_params, postprocess_params)
#    1066 else:
# -> 1067     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~\anaconda3\lib\site-packages\transformers\pipelines\base.py:1074, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1072 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1073     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1074     model_outputs = self.forward(model_inputs, **forward_params)
#    1075     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1076     return outputs
#
# File ~\anaconda3\lib\site-packages\transformers\pipelines\base.py:978, in Pipeline.forward(self, model_inputs, **forward_params)
#     976 if self.framework == "tf":
#     977     model_inputs["training"] = False
# --> 978     model_outputs = self._forward(model_inputs, **forward_params)
#     979 elif self.framework == "pt":
#     980     inference_context = self.get_inference_context()
#
# File ~\anaconda3\lib\site-packages\transformers\pipelines\conversational.py:276, in ConversationalPipeline._forward(self, model_inputs, minimum_tokens, **generate_kwargs)
#     274 conversation = model_inputs.pop("conversation")
#     275 generate_kwargs["max_length"] = max_length
# --> 276 output_ids = self.model.generate(**model_inputs, **generate_kwargs)
#     277 if self.model.config.is_encoder_decoder:
#     278     start_position = 1
#
# File ~\anaconda3\lib\site-packages\transformers\generation_tf_utils.py:583, in TFGenerationMixin.generate(self, input_ids, max_length, max_new_tokens, min_length, do_sample, early_stopping, num_beams, temperature, top_k, top_p, repetition_penalty, bad_words_ids, bos_token_id, pad_token_id, eos_token_id, length_penalty, no_repeat_ngram_size, num_return_sequences, attention_mask, decoder_start_token_id, use_cache, output_scores, output_attentions, output_hidden_states, return_dict_in_generate, forced_bos_token_id, forced_eos_token_id, **model_kwargs)
#     580 do_sample = do_sample if do_sample is not None else self.config.do_sample
#     582 if do_sample is False or num_beams == 1:
# --> 583     return self._generate(
#     584         input_ids=input_ids,
#     585         max_length=max_length,
#     586         max_new_tokens=max_new_tokens,
#     587         min_length=min_length,
#     588         do_sample=do_sample,
#     589         early_stopping=early_stopping,
#     590         num_beams=num_beams,
#     591         temperature=temperature,
#     592         top_k=top_k,
#     593         top_p=top_p,
#     594         repetition_penalty=repetition_penalty,
#     595         bad_words_ids=bad_words_ids,
#     596         bos_token_id=bos_token_id,
#     597         pad_token_id=pad_token_id,
#     598         eos_token_id=eos_token_id,
#     599         length_penalty=length_penalty,
#     600         no_repeat_ngram_size=no_repeat_ngram_size,
#     601         num_return_sequences=num_return_sequences,
#     602         attention_mask=attention_mask,
#     603         decoder_start_token_id=decoder_start_token_id,
#     604         use_cache=use_cache,
#     605         seed=model_kwargs.pop("seed", None),
#     606         output_scores=output_scores,
#     607         output_attentions=output_attentions,
#     608         output_hidden_states=output_hidden_states,
#     609         return_dict_in_generate=return_dict_in_generate,
#     610         forced_bos_token_id=forced_bos_token_id,
#     611         forced_eos_token_id=forced_eos_token_id,
#     612     )
#     614 # We cannot generate if the model does not have a LM head
#     615 if self.get_output_embeddings() is None:
#
# File ~\anaconda3\lib\site-packages\transformers\generation_tf_utils.py:1629, in TFGenerationMixin._generate(self, input_ids, max_length, max_new_tokens, min_length, do_sample, early_stopping, num_beams, temperature, top_k, top_p, repetition_penalty, bad_words_ids, bos_token_id, pad_token_id, eos_token_id, length_penalty, no_repeat_ngram_size, num_return_sequences, attention_mask, decoder_start_token_id, use_cache, seed, output_scores, output_attentions, output_hidden_states, return_dict_in_generate, forced_bos_token_id, forced_eos_token_id, **model_kwargs)
#    1625         raise ValueError(
#    1626             f"num_return_sequences has to be 1, but is {num_return_sequences} when doing greedy search."
#    1627         )
#    1628     # 9. run greedy search
# -> 1629     return self.greedy_search(
#    1630         input_ids,
#    1631         max_length=max_length,
#    1632         pad_token_id=pad_token_id,
#    1633         eos_token_id=eos_token_id,
#    1634         logits_processor=logits_processor,
#    1635         output_scores=output_scores,
#    1636         return_dict_in_generate=return_dict_in_generate,
#    1637         **model_kwargs,
#    1638     )
#    1639 elif is_sample_gen_mode:
#    1640     # 9. prepare logits warper
#    1641     logits_warper = self._get_logits_warper(top_k=top_k, top_p=top_p, temperature=temperature)
#
# File ~\anaconda3\lib\site-packages\transformers\generation_tf_utils.py:2261, in TFGenerationMixin.greedy_search(self, input_ids, max_length, pad_token_id, eos_token_id, logits_processor, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, **model_kwargs)
#    2259 if greedy_search_cond_fn(generated, finished_sequences, cur_len, model_kwargs):
#    2260     maximum_iterations = max_length - cur_len
# -> 2261     generated, _, cur_len, _ = tf.while_loop(
#    2262         greedy_search_cond_fn,
#    2263         greedy_search_body_fn,
#    2264         (generated, finished_sequences, cur_len, model_kwargs),
#    2265         maximum_iterations=maximum_iterations,
#    2266     )
#    2268 # 6. prepare outputs
#    2269 if not use_xla:
#    2270     # cut for backward compatibility
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py:629, in deprecated_arg_values.<locals>.deprecated_wrapper.<locals>.new_func(*args, **kwargs)
#     622           _PRINTED_WARNING[(func, arg_name)] = True
#     623         logging.warning(
#     624             'From %s: calling %s (from %s) with %s=%s is deprecated and '
#     625             'will be removed %s.\nInstructions for updating:\n%s',
#     626             _call_location(), decorator_utils.get_qualified_name(func),
#     627             func.__module__, arg_name, arg_value, 'in a future version'
#     628             if date is None else ('after %s' % date), instructions)
# --> 629 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\ops\control_flow_ops.py:2507, in while_loop_v2(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#    2331 @tf_export("while_loop", v1=[])
#    2332 @deprecation.deprecated_arg_values(
#    2333     None,
#    (...)
#    2348                   maximum_iterations=None,
#    2349                   name=None):
#    2350   """Repeat `body` while the condition `cond` is true.
#    2351
#    2352   `cond` is a callable returning a boolean scalar tensor. `body` is a callable
#    (...)
#    2505
#    2506   """
# -> 2507   return while_loop(
#    2508       cond=cond,
#    2509       body=body,
#    2510       loop_vars=loop_vars,
#    2511       shape_invariants=shape_invariants,
#    2512       parallel_iterations=parallel_iterations,
#    2513       back_prop=back_prop,
#    2514       swap_memory=swap_memory,
#    2515       name=name,
#    2516       maximum_iterations=maximum_iterations,
#    2517       return_same_structure=True)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\ops\control_flow_ops.py:2754, in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#    2751 loop_var_structure = nest.map_structure(type_spec.type_spec_from_value,
#    2752                                         list(loop_vars))
#    2753 while cond(*loop_vars):
# -> 2754   loop_vars = body(*loop_vars)
#    2755   if try_to_pack and not isinstance(loop_vars, (list, _basetuple)):
#    2756     packed = True
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\ops\control_flow_ops.py:2745, in while_loop.<locals>.<lambda>(i, lv)
#    2742     loop_vars = (counter, loop_vars)
#    2743     cond = lambda i, lv: (  # pylint: disable=g-long-lambda
#    2744         math_ops.logical_and(i < maximum_iterations, orig_cond(*lv)))
# -> 2745     body = lambda i, lv: (i + 1, orig_body(*lv))
#    2746   try_to_pack = False
#    2748 if executing_eagerly:
#
# File ~\anaconda3\lib\site-packages\transformers\generation_tf_utils.py:2187, in TFGenerationMixin.greedy_search.<locals>.greedy_search_body_fn(generated, finished_sequences, cur_len, model_kwargs)
#    2185 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2186 # forward pass to get next token logits
# -> 2187 model_outputs = self(
#    2188     **model_inputs,
#    2189     return_dict=True,
#    2190     output_attentions=output_attentions,
#    2191     output_hidden_states=output_hidden_states,
#    2192 )
#    2193 next_token_logits = model_outputs.logits[:, -1]
#    2195 # Store scores, attentions and hidden_states when required
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\keras\engine\training.py:490, in Model.__call__(self, *args, **kwargs)
#     486     super().__call__(inputs, *copied_args, **copied_kwargs)
#     488   layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 490 return super().__call__(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\keras\engine\base_layer.py:1014, in Layer.__call__(self, *args, **kwargs)
#    1010   inputs = self._maybe_cast_inputs(inputs, input_list)
#    1012 with autocast_variable.enable_auto_cast_variables(
#    1013     self._compute_dtype_object):
# -> 1014   outputs = call_fn(inputs, *args, **kwargs)
#    1016 if self._activity_regularizer:
#    1017   self._handle_activity_regularization(inputs, outputs)
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:92, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      90 bound_signature = None
#      91 try:
# ---> 92   return fn(*args, **kwargs)
#      93 except Exception as e:  # pylint: disable=broad-except
#      94   if hasattr(e, '_keras_call_info_injected'):
#      95     # Only inject info for the innermost failing call
#
# File ~\anaconda3\lib\site-packages\transformers\modeling_tf_utils.py:413, in unpack_inputs.<locals>.run_call_with_unpacked_inputs(self, *args, **kwargs)
#     410     config = self.config
#     412 unpacked_inputs = input_processing(func, config, **fn_args_and_kwargs)
# --> 413 return func(self, **unpacked_inputs)
#
# File ~\anaconda3\lib\site-packages\transformers\models\gpt2\modeling_tf_gpt2.py:890, in TFGPT2LMHeadModel.call(self, input_ids, past, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions, output_hidden_states, return_dict, labels, training)
#     840 @unpack_inputs
#     841 @add_start_docstrings_to_model_forward(GPT2_INPUTS_DOCSTRING)
#     842 @add_code_sample_docstrings(
#    (...)
#     864     training: Optional[bool] = False,
#     865 ) -> Union[TFCausalLMOutputWithCrossAttentions, Tuple[tf.Tensor]]:
#     866     r"""
#     867     encoder_hidden_states  (`tf.Tensor` of shape `(batch_size, sequence_length, hidden_size)`, *optional*):
#     868         Sequence of hidden-states at the output of the last layer of the encoder. Used in the cross-attention if
#    (...)
#     887         config.vocab_size - 1]`.
#     888     """
# --> 890     transformer_outputs = self.transformer(
#     891         input_ids=input_ids,
#     892         past=past,
#     893         attention_mask=attention_mask,
#     894         token_type_ids=token_type_ids,
#     895         position_ids=position_ids,
#     896         head_mask=head_mask,
#     897         inputs_embeds=inputs_embeds,
#     898         encoder_hidden_states=encoder_hidden_states,
#     899         encoder_attention_mask=encoder_attention_mask,
#     900         use_cache=use_cache,
#     901         output_attentions=output_attentions,
#     902         output_hidden_states=output_hidden_states,
#     903         return_dict=return_dict,
#     904         training=training,
#     905     )
#     906     hidden_states = transformer_outputs[0]
#     907     logits = self.transformer.wte(hidden_states, mode="linear")
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\keras\engine\base_layer.py:1014, in Layer.__call__(self, *args, **kwargs)
#    1010   inputs = self._maybe_cast_inputs(inputs, input_list)
#    1012 with autocast_variable.enable_auto_cast_variables(
#    1013     self._compute_dtype_object):
# -> 1014   outputs = call_fn(inputs, *args, **kwargs)
#    1016 if self._activity_regularizer:
#    1017   self._handle_activity_regularization(inputs, outputs)
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:92, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      90 bound_signature = None
#      91 try:
# ---> 92   return fn(*args, **kwargs)
#      93 except Exception as e:  # pylint: disable=broad-except
#      94   if hasattr(e, '_keras_call_info_injected'):
#      95     # Only inject info for the innermost failing call
#
# File ~\anaconda3\lib\site-packages\transformers\modeling_tf_utils.py:413, in unpack_inputs.<locals>.run_call_with_unpacked_inputs(self, *args, **kwargs)
#     410     config = self.config
#     412 unpacked_inputs = input_processing(func, config, **fn_args_and_kwargs)
# --> 413 return func(self, **unpacked_inputs)
#
# File ~\anaconda3\lib\site-packages\transformers\models\gpt2\modeling_tf_gpt2.py:470, in TFGPT2MainLayer.call(self, input_ids, past, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions, output_hidden_states, return_dict, training)
#     467 if output_hidden_states:
#     468     all_hidden_states = all_hidden_states + (tf.reshape(hidden_states, output_shape),)
# --> 470 outputs = block(
#     471     hidden_states,
#     472     layer_past,
#     473     attention_mask,
#     474     head_mask[i],
#     475     encoder_hidden_states,
#     476     encoder_attention_mask,
#     477     use_cache,
#     478     output_attentions,
#     479     training=training,
#     480 )
#     482 hidden_states, present = outputs[:2]
#     483 if use_cache:
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\keras\engine\base_layer.py:1014, in Layer.__call__(self, *args, **kwargs)
#    1010   inputs = self._maybe_cast_inputs(inputs, input_list)
#    1012 with autocast_variable.enable_auto_cast_variables(
#    1013     self._compute_dtype_object):
# -> 1014   outputs = call_fn(inputs, *args, **kwargs)
#    1016 if self._activity_regularizer:
#    1017   self._handle_activity_regularization(inputs, outputs)
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:92, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      90 bound_signature = None
#      91 try:
# ---> 92   return fn(*args, **kwargs)
#      93 except Exception as e:  # pylint: disable=broad-except
#      94   if hasattr(e, '_keras_call_info_injected'):
#      95     # Only inject info for the innermost failing call
#
# File ~\anaconda3\lib\site-packages\transformers\models\gpt2\modeling_tf_gpt2.py:296, in TFBlock.call(self, x, layer_past, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions, training)
#     293     outputs = outputs + output_cross_attn[2:]  # add cross attentions if we output attention weights
#     295 m = self.ln_2(x)
# --> 296 m = self.mlp(m, training=training)
#     297 x = x + m
#     299 outputs = [x] + outputs
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\keras\engine\base_layer.py:1014, in Layer.__call__(self, *args, **kwargs)
#    1010   inputs = self._maybe_cast_inputs(inputs, input_list)
#    1012 with autocast_variable.enable_auto_cast_variables(
#    1013     self._compute_dtype_object):
# -> 1014   outputs = call_fn(inputs, *args, **kwargs)
#    1016 if self._activity_regularizer:
#    1017   self._handle_activity_regularization(inputs, outputs)
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:92, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      90 bound_signature = None
#      91 try:
# ---> 92   return fn(*args, **kwargs)
#      93 except Exception as e:  # pylint: disable=broad-except
#      94   if hasattr(e, '_keras_call_info_injected'):
#      95     # Only inject info for the innermost failing call
#
# File ~\anaconda3\lib\site-packages\transformers\models\gpt2\modeling_tf_gpt2.py:218, in TFMLP.call(self, x, training)
#     217 def call(self, x, training=False):
# --> 218     h = self.act(self.c_fc(x))
#     219     h2 = self.c_proj(h)
#     220     h2 = self.dropout(h2, training=training)
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\keras\engine\base_layer.py:1014, in Layer.__call__(self, *args, **kwargs)
#    1010   inputs = self._maybe_cast_inputs(inputs, input_list)
#    1012 with autocast_variable.enable_auto_cast_variables(
#    1013     self._compute_dtype_object):
# -> 1014   outputs = call_fn(inputs, *args, **kwargs)
#    1016 if self._activity_regularizer:
#    1017   self._handle_activity_regularization(inputs, outputs)
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:92, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      90 bound_signature = None
#      91 try:
# ---> 92   return fn(*args, **kwargs)
#      93 except Exception as e:  # pylint: disable=broad-except
#      94   if hasattr(e, '_keras_call_info_injected'):
#      95     # Only inject info for the innermost failing call
#
# File ~\anaconda3\lib\site-packages\transformers\modeling_tf_utils.py:2519, in TFConv1D.call(self, x)
#    2516 bz, sl = shape_list(x)[:2]
#    2518 x = tf.reshape(x, [-1, self.nx])
# -> 2519 x = tf.matmul(x, self.weight) + self.bias
#    2521 x = tf.reshape(x, [bz, sl, self.nf])
#    2523 return x
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3713, in matmul(a, b, transpose_a, transpose_b, adjoint_a, adjoint_b, a_is_sparse, b_is_sparse, output_type, name)
#    3710   return gen_math_ops.batch_mat_mul_v3(
#    3711       a, b, adj_x=adjoint_a, adj_y=adjoint_b, Tout=output_type, name=name)
#    3712 else:
# -> 3713   return gen_math_ops.mat_mul(
#    3714       a, b, transpose_a=transpose_a, transpose_b=transpose_b, name=name)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\ops\gen_math_ops.py:6012, in mat_mul(a, b, transpose_a, transpose_b, name)
#    6010 if tld.is_eager:
#    6011   try:
# -> 6012     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    6013       _ctx, "MatMul", name, a, b, "transpose_a", transpose_a, "transpose_b",
#    6014       transpose_b)
#    6015     return _result
#    6016   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
speaker = gTTS(text=text, lang="en", slow=False)
        speaker.save("res.mp3")
        os.system("start res.mp3")  #macbook->afplay | windows->start
        os.remove("res.mp3")
